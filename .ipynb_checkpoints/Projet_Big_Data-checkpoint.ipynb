# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep
from selenium.webdriver.edge.options import Options
import time
import pymongo

# Initialize WebDriver
options = webdriver.EdgeOptions()
driver = webdriver.Edge(options=options)
driver.get("https://twitter.com/home")

# Your login code...

subject = "chatgpt"



sleep(3)
username = driver.find_element(By.XPATH,"//input[@name='text']")
username.send_keys("   ")  #dir username
next_button = driver.find_element(By.XPATH,"//span[contains(text(),'Suivant')]")
next_button.click()


sleep(3)
password = driver.find_element(By.XPATH,"//input[@name='password']")
password.send_keys('   ') # dir code
log_in = driver.find_element(By.XPATH,"//span[contains(text(),'Se connecter')]")
log_in.click()


# Search item and fetch it
#sleep(3)
#search_box = driver.find_element(By.XPATH,"//input[@data-testid='SearchBox_Search_Input']")
#search_box.send_keys(subject)
#search_box.send_keys(Keys.ENTER)

# Search item and fetch it
sleep(3)
search_box = driver.find_element(By.XPATH,"//input[@data-testid='SearchBox_Search_Input']")
search_box.send_keys(search_query)
search_box.send_keys(Keys.ENTER)


sleep(3)
Latest = driver.find_element(By.XPATH,"//span[contains(text(),'Latest')]")
Latest.click()

extracted_tweets = []

# Scroll to load more tweets
tweet_count = 0
while tweet_count < 20:
    # Extract tweets
    tweets = driver.find_elements(By.XPATH, '//div[@data-testid="tweetText"]')
    tweets_time = driver.find_elements(By.XPATH, '//time[@datetime]')
    
    # Print or store the extracted information
    for tweet, tweet_time in zip(tweets, tweets_time):
        # Print tweet content and time
        print("Content:", tweet.text)
        print("Tweet Time:", tweet_time.get_attribute("datetime"))
        print("=" * 100)
        
        # Store tweet information in a dictionary
        t = {
            "content": tweet.text,
            "date": tweet_time.get_attribute("datetime")
        }
        
        # Append the tweet dictionary to the list
        extracted_tweets.append(t)
        
        tweet_count += 1
        if tweet_count >= 20:
            break
    
    # Scroll down
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # Adjust as needed

# Print extracted tweets
print(extracted_tweets)
